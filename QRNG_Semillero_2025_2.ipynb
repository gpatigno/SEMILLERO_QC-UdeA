# %%
# !pip install qiskit

# %%
# pip install qiskit-ibm-runtime

# %%
# pip install qiskit[visualization]

# %%
# pip install qiskit-aer

# %%
# Importing standard Qiskit libraries

from qiskit import QuantumCircuit
from qiskit import QuantumRegister, ClassicalRegister

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile
from qiskit.visualization import plot_distribution

# Importing standard Qiskit libraries

from qiskit import QuantumCircuit
from qiskit import QuantumRegister, ClassicalRegister

from qiskit.quantum_info import Statevector

# from qiskit.visualization import plot_histogram
from qiskit.visualization import array_to_latex
from qiskit.result import Counts
# from qiskit_aer import AerSimulator

# %%
min = -100
max = 100

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel=<channel>,
            token=<your-API_KEY>, # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard
            instance=<instance_CRN>)

# %%
num_q = 20

q = QuantumRegister(num_q, '')
c = ClassicalRegister(num_q, 'c')

circuit = QuantumCircuit(q, c)

# %%
circuit.h(q)  # Applies hadamard gate to all qubits

circuit.draw('mpl')
# plt.show()

# %%
display(array_to_latex(Statevector(circuit), prefix="\\ket{State_{out}} = "))
# Out:
# $$
# \ket{State_{out}} =
# \begin{bmatrix}
# 0.0009765625 & 0.0009765625 & 0.0009765625 & 0.0009765625 & \cdots & 0.0009765625 & 0.0009765625 & 0.0009765625  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure(q, c)  # Measures all qubits

circuit.draw('mpl')
# plt.show()

# %%
MiSimuladorCuantico = AerSimulator()
job = MiSimuladorCuantico.run(transpile(circuit, MiSimuladorCuantico), shots=1)
conteo = job.result().get_counts(circuit)

# %%
plot_distribution(conteo)

# %%
print('Conteo de resultados por cada medida: ', conteo, '\n')
# Out:
# Conteo de resultados por cada medida:  {'00001111110111000110': 1}

# %%
random_obtained = Counts(conteo).most_frequent()
print(random_obtained)
resultado = int(random_obtained, 2)
# Out:
# 00001111110111000110

# %%
print('El resultado binario como un entero decimal es: ', resultado, '\n')
# Out:
# El resultado binario como un entero decimal es:  64966

# %%
random_number = min + resultado % ((max+1) - min)
print('El numero aleatorio entre',min ,'y',max, 'es:', random_number, '\n')
# Out:
# El numero aleatorio entre -100 y 100 es: -57
